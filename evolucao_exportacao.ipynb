# %%
import pandas as pd # Importação das bibiliotecas que serão utilizadas
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import date
from datetime import timedelta  
import matplotlib.ticker as ticker
import matplotlib.animation as animation
from IPython.display import HTML
from decimal import *
import matplotlib.patches as patches
import matplotlib.cbook as cbook
# %matplotlib inline

# %%
dados = pd.read_csv('EXP_COMPLETA.csv',delimiter=';')

# %%
ncm = pd.read_csv('NCM.csv',delimiter=',',encoding='ansi')

# %%
dados1=dados[dados['CO_NCM']==10011010]
dados2=dados[dados['CO_NCM']==10011090]
dados3=dados[dados['CO_NCM']==10011100]
dados4=dados[dados['CO_NCM']==10011900]
dados5=dados[dados['CO_NCM']==10019010]
dados6=dados[dados['CO_NCM']==10019090]
dados7=dados[dados['CO_NCM']==10019100]
dados8=dados[dados['CO_NCM']==10019900]
dados9=dados[dados['CO_NCM']==11010010]
dados10=dados[dados['CO_NCM']==11010020]
dados11=dados[dados['CO_NCM']==12010010]
dados12=dados[dados['CO_NCM']==12010090]
dados13=dados[dados['CO_NCM']==12011000]
dados14=dados[dados['CO_NCM']==12019000]
dados15=dados[dados['CO_NCM']==15071000]
dados16=dados[dados['CO_NCM']==15079010]
dados17=dados[dados['CO_NCM']==15079011]
dados18=dados[dados['CO_NCM']==15079019]
dados19=dados[dados['CO_NCM']==15079090]
dados20=dados[dados['CO_NCM']==17011100]
dados21=dados[dados['CO_NCM']==17011200]
dados22=dados[dados['CO_NCM']==17011300]
dados23=dados[dados['CO_NCM']==17011400]
dados24=dados[dados['CO_NCM']==17019100]
dados25=dados[dados['CO_NCM']==17019900]
dados26=dados[dados['CO_NCM']==18010000]
dados27=dados[dados['CO_NCM']==18020000]
dados28=dados[dados['CO_NCM']==18031000]
dados29=dados[dados['CO_NCM']==18032000]
dados30=dados[dados['CO_NCM']==18040000]
dados31=dados[dados['CO_NCM']==18050000]
dados32=dados[dados['CO_NCM']==18061000]
dados33=dados[dados['CO_NCM']==18062000]
dados34=dados[dados['CO_NCM']==18063110]
dados35=dados[dados['CO_NCM']==18063120]
dados36=dados[dados['CO_NCM']==18063210]
dados37=dados[dados['CO_NCM']==18063220]
dados38=dados[dados['CO_NCM']==18069000]
dados39=dados[dados['CO_NCM']==20091100]
dados40=dados[dados['CO_NCM']==20091200]
dados41=dados[dados['CO_NCM']==20091900]
dados42=dados[dados['CO_NCM']==23040010]
dados43=dados[dados['CO_NCM']==23040090]
dados44=dados[dados['CO_NCM']==27011100]
dados45=dados[dados['CO_NCM']==27011200]
dados46=dados[dados['CO_NCM']==27011900]
dados47=dados[dados['CO_NCM']==27012000]
dados48=dados[dados['CO_NCM']==27021000]
dados49=dados[dados['CO_NCM']==27022000]
dados50=dados[dados['CO_NCM']==27030000]
dados51=dados[dados['CO_NCM']==27040010]
dados52=dados[dados['CO_NCM']==27040011]
dados53=dados[dados['CO_NCM']==27040012]
dados54=dados[dados['CO_NCM']==27040090]
dados55=dados[dados['CO_NCM']==27090010]
dados56=dados[dados['CO_NCM']==27090090]
dados57=dados[dados['CO_NCM']==27100011]
dados58=dados[dados['CO_NCM']==27100019]
dados59=dados[dados['CO_NCM']==27100021]
dados60=dados[dados['CO_NCM']==27100029]
dados61=dados[dados['CO_NCM']==27100031]
dados62=dados[dados['CO_NCM']==27100039]
dados63=dados[dados['CO_NCM']==27100041]
dados64=dados[dados['CO_NCM']==27100042]
dados65=dados[dados['CO_NCM']==27100049]
dados66=dados[dados['CO_NCM']==27100051]
dados67=dados[dados['CO_NCM']==27100059]
dados68=dados[dados['CO_NCM']==27100061]
dados69=dados[dados['CO_NCM']==27100062]
dados70=dados[dados['CO_NCM']==27100091]
dados71=dados[dados['CO_NCM']==27100092]
dados72=dados[dados['CO_NCM']==27100093]
dados73=dados[dados['CO_NCM']==27100094]
dados74=dados[dados['CO_NCM']==27100095]
dados75=dados[dados['CO_NCM']==27100099]
dados76=dados[dados['CO_NCM']==27101110]
dados77=dados[dados['CO_NCM']==27101121]
dados78=dados[dados['CO_NCM']==27101129]
dados79=dados[dados['CO_NCM']==27101130]
dados80=dados[dados['CO_NCM']==27101141]
dados81=dados[dados['CO_NCM']==27101149]
dados82=dados[dados['CO_NCM']==27101151]
dados83=dados[dados['CO_NCM']==27101159]
dados84=dados[dados['CO_NCM']==27101160]
dados85=dados[dados['CO_NCM']==27101190]
dados86=dados[dados['CO_NCM']==27101210]
dados87=dados[dados['CO_NCM']==27101221]
dados88=dados[dados['CO_NCM']==27101229]
dados89=dados[dados['CO_NCM']==27101230]
dados90=dados[dados['CO_NCM']==27101241]
dados91=dados[dados['CO_NCM']==27101249]
dados92=dados[dados['CO_NCM']==27101251]
dados93=dados[dados['CO_NCM']==27101259]
dados94=dados[dados['CO_NCM']==27101260]
dados95=dados[dados['CO_NCM']==27101290]
dados96=dados[dados['CO_NCM']==27101911]
dados97=dados[dados['CO_NCM']==27101919]
dados98=dados[dados['CO_NCM']==27101921]
dados99=dados[dados['CO_NCM']==27101922]
dados100=dados[dados['CO_NCM']==27101929]
dados101=dados[dados['CO_NCM']==27101931]
dados102=dados[dados['CO_NCM']==27101932]
dados103=dados[dados['CO_NCM']==27101991]
dados104=dados[dados['CO_NCM']==27101992]
dados105=dados[dados['CO_NCM']==27101993]
dados106=dados[dados['CO_NCM']==27101994]
dados107=dados[dados['CO_NCM']==27101999]
dados108=dados[dados['CO_NCM']==27102000]
dados109=dados[dados['CO_NCM']==27109100]
dados110=dados[dados['CO_NCM']==27109900]
dados111=dados[dados['CO_NCM']==27111100]
dados112=dados[dados['CO_NCM']==27111210]
dados113=dados[dados['CO_NCM']==27111290]
dados114=dados[dados['CO_NCM']==27111300]
dados115=dados[dados['CO_NCM']==27111400]
dados116=dados[dados['CO_NCM']==27111910]
dados117=dados[dados['CO_NCM']==27111990]
dados118=dados[dados['CO_NCM']==27112100]
dados119=dados[dados['CO_NCM']==27112910]
dados120=dados[dados['CO_NCM']==27112990]
dados121=dados[dados['CO_NCM']==52010010]
dados122=dados[dados['CO_NCM']==52010020]
dados123=dados[dados['CO_NCM']==52010090]
dados124=dados[dados['CO_NCM']==52021000]
dados125=dados[dados['CO_NCM']==52029100]
dados126=dados[dados['CO_NCM']==52029900]
dados127=dados[dados['CO_NCM']==52030000]
dados128=dados[dados['CO_NCM']==52041111]
dados129=dados[dados['CO_NCM']==52041112]
dados130=dados[dados['CO_NCM']==52041120]
dados131=dados[dados['CO_NCM']==52041131]
dados132=dados[dados['CO_NCM']==52041132]
dados133=dados[dados['CO_NCM']==52041140]
dados134=dados[dados['CO_NCM']==52041911]
dados135=dados[dados['CO_NCM']==52041912]
dados136=dados[dados['CO_NCM']==52041920]
dados137=dados[dados['CO_NCM']==52041931]
dados138=dados[dados['CO_NCM']==52041932]
dados139=dados[dados['CO_NCM']==52041940]
dados140=dados[dados['CO_NCM']==52042000]
dados141=dados[dados['CO_NCM']==52051100]
dados142=dados[dados['CO_NCM']==52051200]
dados143=dados[dados['CO_NCM']==52051310]
dados144=dados[dados['CO_NCM']==52051390]
dados145=dados[dados['CO_NCM']==52051400]
dados146=dados[dados['CO_NCM']==52051500]
dados147=dados[dados['CO_NCM']==52052100]
dados148=dados[dados['CO_NCM']==52052200]
dados149=dados[dados['CO_NCM']==52052310]
dados150=dados[dados['CO_NCM']==52052390]
dados151=dados[dados['CO_NCM']==52052400]
dados152=dados[dados['CO_NCM']==52052600]
dados153=dados[dados['CO_NCM']==52052700]
dados154=dados[dados['CO_NCM']==52052800]
dados155=dados[dados['CO_NCM']==52053100]
dados156=dados[dados['CO_NCM']==52053200]
dados157=dados[dados['CO_NCM']==52053300]
dados158=dados[dados['CO_NCM']==52053400]
dados159=dados[dados['CO_NCM']==52053500]
dados160=dados[dados['CO_NCM']==52054100]
dados161=dados[dados['CO_NCM']==52054200]
dados162=dados[dados['CO_NCM']==52054300]
dados163=dados[dados['CO_NCM']==52054400]
dados164=dados[dados['CO_NCM']==52054600]
dados165=dados[dados['CO_NCM']==52054700]
dados166=dados[dados['CO_NCM']==52054800]
dados167=dados[dados['CO_NCM']==52061100]
dados168=dados[dados['CO_NCM']==52061200]
dados169=dados[dados['CO_NCM']==52061300]
dados170=dados[dados['CO_NCM']==52061400]
dados171=dados[dados['CO_NCM']==52061500]
dados172=dados[dados['CO_NCM']==52062100]
dados173=dados[dados['CO_NCM']==52062200]
dados174=dados[dados['CO_NCM']==52062300]
dados175=dados[dados['CO_NCM']==52062400]
dados176=dados[dados['CO_NCM']==52062500]
dados177=dados[dados['CO_NCM']==52063100]
dados178=dados[dados['CO_NCM']==52063200]
dados179=dados[dados['CO_NCM']==52063300]
dados180=dados[dados['CO_NCM']==52063400]
dados181=dados[dados['CO_NCM']==52063500]
dados182=dados[dados['CO_NCM']==52064100]
dados183=dados[dados['CO_NCM']==52064200]
dados184=dados[dados['CO_NCM']==52064300]
dados185=dados[dados['CO_NCM']==52064400]
dados186=dados[dados['CO_NCM']==52064500]
dados187=dados[dados['CO_NCM']==52071000]
dados188=dados[dados['CO_NCM']==52079000]
dados189=dados[dados['CO_NCM']==52081100]
dados190=dados[dados['CO_NCM']==52081200]
dados191=dados[dados['CO_NCM']==52081300]
dados192=dados[dados['CO_NCM']==52081900]
dados193=dados[dados['CO_NCM']==52082100]
dados194=dados[dados['CO_NCM']==52082200]
dados195=dados[dados['CO_NCM']==52082300]
dados196=dados[dados['CO_NCM']==52082900]
dados197=dados[dados['CO_NCM']==52083100]
dados198=dados[dados['CO_NCM']==52083200]
dados199=dados[dados['CO_NCM']==52083300]
dados200=dados[dados['CO_NCM']==52083900]
dados201=dados[dados['CO_NCM']==52084100]
dados202=dados[dados['CO_NCM']==52084200]
dados203=dados[dados['CO_NCM']==52084300]
dados204=dados[dados['CO_NCM']==52084900]
dados205=dados[dados['CO_NCM']==52085100]
dados206=dados[dados['CO_NCM']==52085200]
dados207=dados[dados['CO_NCM']==52085300]
dados208=dados[dados['CO_NCM']==52085900]
dados209=dados[dados['CO_NCM']==52085910]
dados210=dados[dados['CO_NCM']==52085990]
dados211=dados[dados['CO_NCM']==52091100]
dados212=dados[dados['CO_NCM']==52091200]
dados213=dados[dados['CO_NCM']==52091900]
dados214=dados[dados['CO_NCM']==52092100]
dados215=dados[dados['CO_NCM']==52092200]
dados216=dados[dados['CO_NCM']==52092900]
dados217=dados[dados['CO_NCM']==52093100]
dados218=dados[dados['CO_NCM']==52093200]
dados219=dados[dados['CO_NCM']==52093900]
dados220=dados[dados['CO_NCM']==52094100]
dados221=dados[dados['CO_NCM']==52094210]
dados222=dados[dados['CO_NCM']==52094290]
dados223=dados[dados['CO_NCM']==52094300]
dados224=dados[dados['CO_NCM']==52094900]
dados225=dados[dados['CO_NCM']==52095100]
dados226=dados[dados['CO_NCM']==52095200]
dados227=dados[dados['CO_NCM']==52095900]
dados228=dados[dados['CO_NCM']==52101100]
dados229=dados[dados['CO_NCM']==52101200]
dados230=dados[dados['CO_NCM']==52101900]
dados231=dados[dados['CO_NCM']==52101910]
dados232=dados[dados['CO_NCM']==52101990]
dados233=dados[dados['CO_NCM']==52102100]
dados234=dados[dados['CO_NCM']==52102200]
dados235=dados[dados['CO_NCM']==52102900]
dados236=dados[dados['CO_NCM']==52102910]
dados237=dados[dados['CO_NCM']==52102990]
dados238=dados[dados['CO_NCM']==52103100]
dados239=dados[dados['CO_NCM']==52103200]
dados240=dados[dados['CO_NCM']==52103900]
dados241=dados[dados['CO_NCM']==52104100]
dados242=dados[dados['CO_NCM']==52104200]
dados243=dados[dados['CO_NCM']==52104900]
dados244=dados[dados['CO_NCM']==52104910]
dados245=dados[dados['CO_NCM']==52104990]
dados246=dados[dados['CO_NCM']==52105100]
dados247=dados[dados['CO_NCM']==52105200]
dados248=dados[dados['CO_NCM']==52105900]
dados249=dados[dados['CO_NCM']==52105910]
dados250=dados[dados['CO_NCM']==52105990]
dados251=dados[dados['CO_NCM']==52111100]
dados252=dados[dados['CO_NCM']==52111200]
dados253=dados[dados['CO_NCM']==52111900]
dados254=dados[dados['CO_NCM']==52112010]
dados255=dados[dados['CO_NCM']==52112020]
dados256=dados[dados['CO_NCM']==52112090]
dados257=dados[dados['CO_NCM']==52112100]
dados258=dados[dados['CO_NCM']==52112200]
dados259=dados[dados['CO_NCM']==52112900]
dados260=dados[dados['CO_NCM']==52113100]
dados261=dados[dados['CO_NCM']==52113200]
dados262=dados[dados['CO_NCM']==52113900]
dados263=dados[dados['CO_NCM']==52114100]
dados264=dados[dados['CO_NCM']==52114210]
dados265=dados[dados['CO_NCM']==52114290]
dados266=dados[dados['CO_NCM']==52114300]
dados267=dados[dados['CO_NCM']==52114900]
dados268=dados[dados['CO_NCM']==52115100]
dados269=dados[dados['CO_NCM']==52115200]
dados270=dados[dados['CO_NCM']==52115900]
dados271=dados[dados['CO_NCM']==52121100]
dados272=dados[dados['CO_NCM']==52121200]
dados273=dados[dados['CO_NCM']==52121300]
dados274=dados[dados['CO_NCM']==52121400]
dados275=dados[dados['CO_NCM']==52121500]
dados276=dados[dados['CO_NCM']==52122100]
dados277=dados[dados['CO_NCM']==52122200]
dados278=dados[dados['CO_NCM']==52122300]
dados279=dados[dados['CO_NCM']==52122400]
dados280=dados[dados['CO_NCM']==52122500]
dados281=dados[dados['CO_NCM']==71061000]
dados282=dados[dados['CO_NCM']==71069100]
dados283=dados[dados['CO_NCM']==71069210]
dados284=dados[dados['CO_NCM']==71069220]
dados285=dados[dados['CO_NCM']==71069290]
dados286=dados[dados['CO_NCM']==71081100]
dados287=dados[dados['CO_NCM']==71081200]
dados288=dados[dados['CO_NCM']==71081210]
dados289=dados[dados['CO_NCM']==71081290]
dados290=dados[dados['CO_NCM']==71081310]
dados291=dados[dados['CO_NCM']==71081311]
dados292=dados[dados['CO_NCM']==71081319]
dados293=dados[dados['CO_NCM']==71081390]
dados294=dados[dados['CO_NCM']==71081391]
dados295=dados[dados['CO_NCM']==71081399]
dados296=dados[dados['CO_NCM']==71082000]
dados297=dados[dados['CO_NCM']==72011000]
dados298=dados[dados['CO_NCM']==72012000]
dados299=dados[dados['CO_NCM']==72015000]
dados300=dados[dados['CO_NCM']==72021100]
dados301=dados[dados['CO_NCM']==72021900]
dados302=dados[dados['CO_NCM']==72022100]
dados303=dados[dados['CO_NCM']==72022900]
dados304=dados[dados['CO_NCM']==72023000]
dados305=dados[dados['CO_NCM']==72024100]
dados306=dados[dados['CO_NCM']==72024900]
dados307=dados[dados['CO_NCM']==72025000]
dados308=dados[dados['CO_NCM']==72026000]
dados309=dados[dados['CO_NCM']==72027000]
dados310=dados[dados['CO_NCM']==72028000]
dados311=dados[dados['CO_NCM']==72029100]
dados312=dados[dados['CO_NCM']==72029200]
dados313=dados[dados['CO_NCM']==72029300]
dados314=dados[dados['CO_NCM']==72029910]
dados315=dados[dados['CO_NCM']==72029990]
dados316=dados[dados['CO_NCM']==72031000]
dados317=dados[dados['CO_NCM']==72039000]
dados318=dados[dados['CO_NCM']==72041000]
dados319=dados[dados['CO_NCM']==72042100]
dados320=dados[dados['CO_NCM']==72042900]
dados321=dados[dados['CO_NCM']==72043000]
dados322=dados[dados['CO_NCM']==72044100]
dados323=dados[dados['CO_NCM']==72044900]
dados324=dados[dados['CO_NCM']==72045000]
dados325=dados[dados['CO_NCM']==72051000]
dados326=dados[dados['CO_NCM']==72052100]
dados327=dados[dados['CO_NCM']==72052910]
dados328=dados[dados['CO_NCM']==72052920]
dados329=dados[dados['CO_NCM']==72052990]
dados330=dados[dados['CO_NCM']==72061000]
dados331=dados[dados['CO_NCM']==72069000]
dados332=dados[dados['CO_NCM']==72071110]
dados333=dados[dados['CO_NCM']==72071190]
dados334=dados[dados['CO_NCM']==72071200]
dados335=dados[dados['CO_NCM']==72071900]
dados336=dados[dados['CO_NCM']==72072000]
dados337=dados[dados['CO_NCM']==72081000]
dados338=dados[dados['CO_NCM']==72082500]
dados339=dados[dados['CO_NCM']==72082610]
dados340=dados[dados['CO_NCM']==72082690]
dados341=dados[dados['CO_NCM']==72082710]
dados342=dados[dados['CO_NCM']==72082790]
dados343=dados[dados['CO_NCM']==72083610]
dados344=dados[dados['CO_NCM']==72083690]
dados345=dados[dados['CO_NCM']==72083700]
dados346=dados[dados['CO_NCM']==72083810]
dados347=dados[dados['CO_NCM']==72083890]
dados348=dados[dados['CO_NCM']==72083910]
dados349=dados[dados['CO_NCM']==72083990]
dados350=dados[dados['CO_NCM']==72084000]
dados351=dados[dados['CO_NCM']==72085100]
dados352=dados[dados['CO_NCM']==72085200]
dados353=dados[dados['CO_NCM']==72085300]
dados354=dados[dados['CO_NCM']==72085400]
dados355=dados[dados['CO_NCM']==72089000]
dados356=dados[dados['CO_NCM']==72091500]
dados357=dados[dados['CO_NCM']==72091600]
dados358=dados[dados['CO_NCM']==72091700]
dados359=dados[dados['CO_NCM']==72091800]
dados360=dados[dados['CO_NCM']==72092500]
dados361=dados[dados['CO_NCM']==72092600]
dados362=dados[dados['CO_NCM']==72092700]
dados363=dados[dados['CO_NCM']==72092800]
dados364=dados[dados['CO_NCM']==72099000]
dados365=dados[dados['CO_NCM']==72101100]
dados366=dados[dados['CO_NCM']==72101200]
dados367=dados[dados['CO_NCM']==72102000]
dados368=dados[dados['CO_NCM']==72103010]
dados369=dados[dados['CO_NCM']==72103090]
dados370=dados[dados['CO_NCM']==72104110]
dados371=dados[dados['CO_NCM']==72104190]
dados372=dados[dados['CO_NCM']==72104910]
dados373=dados[dados['CO_NCM']==72104990]
dados374=dados[dados['CO_NCM']==72105000]
dados375=dados[dados['CO_NCM']==72106100]
dados376=dados[dados['CO_NCM']==72106900]
dados377=dados[dados['CO_NCM']==72106911]
dados378=dados[dados['CO_NCM']==72106919]
dados379=dados[dados['CO_NCM']==72106990]
dados380=dados[dados['CO_NCM']==72107010]
dados381=dados[dados['CO_NCM']==72107020]
dados382=dados[dados['CO_NCM']==72109000]
dados383=dados[dados['CO_NCM']==72111300]
dados384=dados[dados['CO_NCM']==72111400]
dados385=dados[dados['CO_NCM']==72111900]
dados386=dados[dados['CO_NCM']==72112300]
dados387=dados[dados['CO_NCM']==72112910]
dados388=dados[dados['CO_NCM']==72112920]
dados389=dados[dados['CO_NCM']==72119010]
dados390=dados[dados['CO_NCM']==72119090]
dados391=dados[dados['CO_NCM']==72121000]
dados392=dados[dados['CO_NCM']==72122010]
dados393=dados[dados['CO_NCM']==72122090]
dados394=dados[dados['CO_NCM']==72123000]
dados395=dados[dados['CO_NCM']==72124010]
dados396=dados[dados['CO_NCM']==72124020]
dados397=dados[dados['CO_NCM']==72124021]
dados398=dados[dados['CO_NCM']==72124029]
dados399=dados[dados['CO_NCM']==72125000]
dados400=dados[dados['CO_NCM']==72125010]
dados401=dados[dados['CO_NCM']==72125090]
dados402=dados[dados['CO_NCM']==72126000]
dados403=dados[dados['CO_NCM']==72131000]
dados404=dados[dados['CO_NCM']==72132000]
dados405=dados[dados['CO_NCM']==72139110]
dados406=dados[dados['CO_NCM']==72139190]
dados407=dados[dados['CO_NCM']==72139910]
dados408=dados[dados['CO_NCM']==72139990]
dados409=dados[dados['CO_NCM']==72141010]
dados410=dados[dados['CO_NCM']==72141090]
dados411=dados[dados['CO_NCM']==72142000]
dados412=dados[dados['CO_NCM']==72143000]
dados413=dados[dados['CO_NCM']==72149100]
dados414=dados[dados['CO_NCM']==72149910]
dados415=dados[dados['CO_NCM']==72149990]
dados416=dados[dados['CO_NCM']==72151000]
dados417=dados[dados['CO_NCM']==72155000]
dados418=dados[dados['CO_NCM']==72159010]
dados419=dados[dados['CO_NCM']==72159090]
dados420=dados[dados['CO_NCM']==72161000]
dados421=dados[dados['CO_NCM']==72162100]
dados422=dados[dados['CO_NCM']==72162200]
dados423=dados[dados['CO_NCM']==72163100]
dados424=dados[dados['CO_NCM']==72163200]
dados425=dados[dados['CO_NCM']==72163300]
dados426=dados[dados['CO_NCM']==72164010]
dados427=dados[dados['CO_NCM']==72164090]
dados428=dados[dados['CO_NCM']==72165000]
dados429=dados[dados['CO_NCM']==72166110]
dados430=dados[dados['CO_NCM']==72166190]
dados431=dados[dados['CO_NCM']==72166910]
dados432=dados[dados['CO_NCM']==72166990]
dados433=dados[dados['CO_NCM']==72169100]
dados434=dados[dados['CO_NCM']==72169900]
dados435=dados[dados['CO_NCM']==72171010]
dados436=dados[dados['CO_NCM']==72171011]
dados437=dados[dados['CO_NCM']==72171019]
dados438=dados[dados['CO_NCM']==72171090]
dados439=dados[dados['CO_NCM']==72172010]
dados440=dados[dados['CO_NCM']==72172090]
dados441=dados[dados['CO_NCM']==72173010]
dados442=dados[dados['CO_NCM']==72173090]
dados443=dados[dados['CO_NCM']==72179000]
dados444=dados[dados['CO_NCM']==72181000]
dados445=dados[dados['CO_NCM']==72189100]
dados446=dados[dados['CO_NCM']==72189900]
dados447=dados[dados['CO_NCM']==72191100]
dados448=dados[dados['CO_NCM']==72191200]
dados449=dados[dados['CO_NCM']==72191300]
dados450=dados[dados['CO_NCM']==72191400]
dados451=dados[dados['CO_NCM']==72192100]
dados452=dados[dados['CO_NCM']==72192200]
dados453=dados[dados['CO_NCM']==72192300]
dados454=dados[dados['CO_NCM']==72192400]
dados455=dados[dados['CO_NCM']==72193100]
dados456=dados[dados['CO_NCM']==72193200]
dados457=dados[dados['CO_NCM']==72193300]
dados458=dados[dados['CO_NCM']==72193400]
dados459=dados[dados['CO_NCM']==72193500]
dados460=dados[dados['CO_NCM']==72199010]
dados461=dados[dados['CO_NCM']==72199090]
dados462=dados[dados['CO_NCM']==72201100]
dados463=dados[dados['CO_NCM']==72201210]
dados464=dados[dados['CO_NCM']==72201220]
dados465=dados[dados['CO_NCM']==72201290]
dados466=dados[dados['CO_NCM']==72202010]
dados467=dados[dados['CO_NCM']==72202090]
dados468=dados[dados['CO_NCM']==72209000]
dados469=dados[dados['CO_NCM']==72210000]
dados470=dados[dados['CO_NCM']==72221100]
dados471=dados[dados['CO_NCM']==72221910]
dados472=dados[dados['CO_NCM']==72221990]
dados473=dados[dados['CO_NCM']==72222000]
dados474=dados[dados['CO_NCM']==72223000]
dados475=dados[dados['CO_NCM']==72224010]
dados476=dados[dados['CO_NCM']==72224090]
dados477=dados[dados['CO_NCM']==72230000]
dados478=dados[dados['CO_NCM']==72241000]
dados479=dados[dados['CO_NCM']==72249000]
dados480=dados[dados['CO_NCM']==72251100]
dados481=dados[dados['CO_NCM']==72251900]
dados482=dados[dados['CO_NCM']==72252000]
dados483=dados[dados['CO_NCM']==72253000]
dados484=dados[dados['CO_NCM']==72254010]
dados485=dados[dados['CO_NCM']==72254020]
dados486=dados[dados['CO_NCM']==72254090]
dados487=dados[dados['CO_NCM']==72255000]
dados488=dados[dados['CO_NCM']==72255010]
dados489=dados[dados['CO_NCM']==72255090]
dados490=dados[dados['CO_NCM']==72259100]
dados491=dados[dados['CO_NCM']==72259200]
dados492=dados[dados['CO_NCM']==72259900]
dados493=dados[dados['CO_NCM']==72259910]
dados494=dados[dados['CO_NCM']==72259990]
dados495=dados[dados['CO_NCM']==72261100]
dados496=dados[dados['CO_NCM']==72261900]
dados497=dados[dados['CO_NCM']==72262010]
dados498=dados[dados['CO_NCM']==72262090]
dados499=dados[dados['CO_NCM']==72269100]
dados500=dados[dados['CO_NCM']==72269200]
dados501=dados[dados['CO_NCM']==72269300]
dados502=dados[dados['CO_NCM']==72269400]
dados503=dados[dados['CO_NCM']==72269900]
dados504=dados[dados['CO_NCM']==72271000]
dados505=dados[dados['CO_NCM']==72272000]
dados506=dados[dados['CO_NCM']==72279000]
dados507=dados[dados['CO_NCM']==72281010]
dados508=dados[dados['CO_NCM']==72281090]
dados509=dados[dados['CO_NCM']==72282000]
dados510=dados[dados['CO_NCM']==72283000]
dados511=dados[dados['CO_NCM']==72284000]
dados512=dados[dados['CO_NCM']==72285000]
dados513=dados[dados['CO_NCM']==72286000]
dados514=dados[dados['CO_NCM']==72287000]
dados515=dados[dados['CO_NCM']==72288000]
dados516=dados[dados['CO_NCM']==72291000]
dados517=dados[dados['CO_NCM']==72292000]
dados518=dados[dados['CO_NCM']==72299000]
dados519=dados[dados['CO_NCM']==74010000]
dados520=dados[dados['CO_NCM']==74011000]
dados521=dados[dados['CO_NCM']==74012000]
dados522=dados[dados['CO_NCM']==74020000]
dados523=dados[dados['CO_NCM']==74031100]
dados524=dados[dados['CO_NCM']==74031200]
dados525=dados[dados['CO_NCM']==74031300]
dados526=dados[dados['CO_NCM']==74031900]
dados527=dados[dados['CO_NCM']==74032100]
dados528=dados[dados['CO_NCM']==74032200]
dados529=dados[dados['CO_NCM']==74032300]
dados530=dados[dados['CO_NCM']==74032900]
dados531=dados[dados['CO_NCM']==74040000]
dados532=dados[dados['CO_NCM']==74050000]
dados533=dados[dados['CO_NCM']==74061000]
dados534=dados[dados['CO_NCM']==74062000]
dados535=dados[dados['CO_NCM']==74071010]
dados536=dados[dados['CO_NCM']==74071021]
dados537=dados[dados['CO_NCM']==74071029]
dados538=dados[dados['CO_NCM']==74072110]
dados539=dados[dados['CO_NCM']==74072120]
dados540=dados[dados['CO_NCM']==74072210]
dados541=dados[dados['CO_NCM']==74072220]
dados542=dados[dados['CO_NCM']==74072910]
dados543=dados[dados['CO_NCM']==74072921]
dados544=dados[dados['CO_NCM']==74072929]
dados545=dados[dados['CO_NCM']==74081100]
dados546=dados[dados['CO_NCM']==74081900]
dados547=dados[dados['CO_NCM']==74082100]
dados548=dados[dados['CO_NCM']==74082200]
dados549=dados[dados['CO_NCM']==74082911]
dados550=dados[dados['CO_NCM']==74082919]
dados551=dados[dados['CO_NCM']==74082990]
dados552=dados[dados['CO_NCM']==74091100]
dados553=dados[dados['CO_NCM']==74091900]
dados554=dados[dados['CO_NCM']==74092100]
dados555=dados[dados['CO_NCM']==74092900]
dados556=dados[dados['CO_NCM']==74093100]
dados557=dados[dados['CO_NCM']==74093111]
dados558=dados[dados['CO_NCM']==74093119]
dados559=dados[dados['CO_NCM']==74093190]
dados560=dados[dados['CO_NCM']==74093900]
dados561=dados[dados['CO_NCM']==74094010]
dados562=dados[dados['CO_NCM']==74094090]
dados563=dados[dados['CO_NCM']==74099000]
dados564=dados[dados['CO_NCM']==74101110]
dados565=dados[dados['CO_NCM']==74101111]
dados566=dados[dados['CO_NCM']==74101112]
dados567=dados[dados['CO_NCM']==74101113]
dados568=dados[dados['CO_NCM']==74101119]
dados569=dados[dados['CO_NCM']==74101190]
dados570=dados[dados['CO_NCM']==74101200]
dados571=dados[dados['CO_NCM']==74102110]
dados572=dados[dados['CO_NCM']==74102120]
dados573=dados[dados['CO_NCM']==74102130]
dados574=dados[dados['CO_NCM']==74102190]
dados575=dados[dados['CO_NCM']==74102200]
dados576=dados[dados['CO_NCM']==74111010]
dados577=dados[dados['CO_NCM']==74111090]
dados578=dados[dados['CO_NCM']==74112110]
dados579=dados[dados['CO_NCM']==74112190]
dados580=dados[dados['CO_NCM']==74112210]
dados581=dados[dados['CO_NCM']==74112290]
dados582=dados[dados['CO_NCM']==74112910]
dados583=dados[dados['CO_NCM']==74112990]
dados584=dados[dados['CO_NCM']==74121000]
dados585=dados[dados['CO_NCM']==74122000]
dados586=dados[dados['CO_NCM']==74130000]
dados587=dados[dados['CO_NCM']==74142000]
dados588=dados[dados['CO_NCM']==74149000]
dados589=dados[dados['CO_NCM']==74151000]
dados590=dados[dados['CO_NCM']==74152100]
dados591=dados[dados['CO_NCM']==74152900]
dados592=dados[dados['CO_NCM']==74153100]
dados593=dados[dados['CO_NCM']==74153200]
dados594=dados[dados['CO_NCM']==74153300]
dados595=dados[dados['CO_NCM']==74153900]
dados596=dados[dados['CO_NCM']==74160000]
dados597=dados[dados['CO_NCM']==74170000]
dados598=dados[dados['CO_NCM']==74181000]
dados599=dados[dados['CO_NCM']==74181100]
dados600=dados[dados['CO_NCM']==74181900]
dados601=dados[dados['CO_NCM']==74182000]
dados602=dados[dados['CO_NCM']==74191000]
dados603=dados[dados['CO_NCM']==74199100]
dados604=dados[dados['CO_NCM']==74199900]
dados605=dados[dados['CO_NCM']==74199910]
dados606=dados[dados['CO_NCM']==74199920]
dados607=dados[dados['CO_NCM']==74199930]
dados608=dados[dados['CO_NCM']==74199990]
dados609=dados[dados['CO_NCM']==76011000]
dados610=dados[dados['CO_NCM']==76012000]
dados611=dados[dados['CO_NCM']==76020000]
dados612=dados[dados['CO_NCM']==76031000]
dados613=dados[dados['CO_NCM']==76032000]
dados614=dados[dados['CO_NCM']==76041010]
dados615=dados[dados['CO_NCM']==76041021]
dados616=dados[dados['CO_NCM']==76041029]
dados617=dados[dados['CO_NCM']==76042100]
dados618=dados[dados['CO_NCM']==76042911]
dados619=dados[dados['CO_NCM']==76042919]
dados620=dados[dados['CO_NCM']==76042920]
dados621=dados[dados['CO_NCM']==76051110]
dados622=dados[dados['CO_NCM']==76051190]
dados623=dados[dados['CO_NCM']==76051910]
dados624=dados[dados['CO_NCM']==76051990]
dados625=dados[dados['CO_NCM']==76052110]
dados626=dados[dados['CO_NCM']==76052190]
dados627=dados[dados['CO_NCM']==76052910]
dados628=dados[dados['CO_NCM']==76052990]
dados629=dados[dados['CO_NCM']==76061100]
dados630=dados[dados['CO_NCM']==76061110]
dados631=dados[dados['CO_NCM']==76061190]
dados632=dados[dados['CO_NCM']==76061210]
dados633=dados[dados['CO_NCM']==76061220]
dados634=dados[dados['CO_NCM']==76061290]
dados635=dados[dados['CO_NCM']==76069100]
dados636=dados[dados['CO_NCM']==76069200]
dados637=dados[dados['CO_NCM']==76071100]
dados638=dados[dados['CO_NCM']==76071110]
dados639=dados[dados['CO_NCM']==76071190]
dados640=dados[dados['CO_NCM']==76071910]
dados641=dados[dados['CO_NCM']==76071990]
dados642=dados[dados['CO_NCM']==76072000]
dados643=dados[dados['CO_NCM']==76081000]
dados644=dados[dados['CO_NCM']==76082000]
dados645=dados[dados['CO_NCM']==76082010]
dados646=dados[dados['CO_NCM']==76082090]
dados647=dados[dados['CO_NCM']==76090000]
dados648=dados[dados['CO_NCM']==76101000]
dados649=dados[dados['CO_NCM']==76109000]
dados650=dados[dados['CO_NCM']==76110000]
dados651=dados[dados['CO_NCM']==76121000]
dados652=dados[dados['CO_NCM']==76129011]
dados653=dados[dados['CO_NCM']==76129012]
dados654=dados[dados['CO_NCM']==76129019]
dados655=dados[dados['CO_NCM']==76129090]
dados656=dados[dados['CO_NCM']==76130000]
dados657=dados[dados['CO_NCM']==76141010]
dados658=dados[dados['CO_NCM']==76141090]
dados659=dados[dados['CO_NCM']==76149010]
dados660=dados[dados['CO_NCM']==76149090]
dados661=dados[dados['CO_NCM']==76151000]
dados662=dados[dados['CO_NCM']==76151100]
dados663=dados[dados['CO_NCM']==76151900]
dados664=dados[dados['CO_NCM']==76152000]
dados665=dados[dados['CO_NCM']==76161000]
dados666=dados[dados['CO_NCM']==76169100]
dados667=dados[dados['CO_NCM']==76169900]
dados668=dados[dados['CO_NCM']==80011000]
dados669=dados[dados['CO_NCM']==80012000]
dados670=dados[dados['CO_NCM']==80020000]
dados671=dados[dados['CO_NCM']==80030000]
dados672=dados[dados['CO_NCM']==80040000]
dados673=dados[dados['CO_NCM']==80050010]
dados674=dados[dados['CO_NCM']==80050020]
dados675=dados[dados['CO_NCM']==80060000]
dados676=dados[dados['CO_NCM']==80070000]
dados677=dados[dados['CO_NCM']==80070010]
dados678=dados[dados['CO_NCM']==80070020]
dados679=dados[dados['CO_NCM']==80070030]
dados680=dados[dados['CO_NCM']==80070090]
dados681=dados[dados['CO_NCM']==81110010]
dados682=dados[dados['CO_NCM']==81110020]
dados683=dados[dados['CO_NCM']==81110090]
dados684=dados[dados['CO_NCM']==2011000]
dados685=dados[dados['CO_NCM']==2012010]
dados686=dados[dados['CO_NCM']==2012020]
dados687=dados[dados['CO_NCM']==2012090]
dados688=dados[dados['CO_NCM']==2013000]
dados689=dados[dados['CO_NCM']==2021000]
dados690=dados[dados['CO_NCM']==2022010]
dados691=dados[dados['CO_NCM']==2022020]
dados692=dados[dados['CO_NCM']==2022090]
dados693=dados[dados['CO_NCM']==2023000]
dados694=dados[dados['CO_NCM']==2031100]
dados695=dados[dados['CO_NCM']==2031200]
dados696=dados[dados['CO_NCM']==2031900]
dados697=dados[dados['CO_NCM']==2032100]
dados698=dados[dados['CO_NCM']==2032200]
dados699=dados[dados['CO_NCM']==2032900]
dados700=dados[dados['CO_NCM']==2041000]
dados701=dados[dados['CO_NCM']==2042100]
dados702=dados[dados['CO_NCM']==2042200]
dados703=dados[dados['CO_NCM']==2042300]
dados704=dados[dados['CO_NCM']==2043000]
dados705=dados[dados['CO_NCM']==2044100]
dados706=dados[dados['CO_NCM']==2044200]
dados707=dados[dados['CO_NCM']==2044300]
dados708=dados[dados['CO_NCM']==2045000]
dados709=dados[dados['CO_NCM']==2050000]
dados710=dados[dados['CO_NCM']==2061000]
dados711=dados[dados['CO_NCM']==2062100]
dados712=dados[dados['CO_NCM']==2062200]
dados713=dados[dados['CO_NCM']==2062910]
dados714=dados[dados['CO_NCM']==2062990]
dados715=dados[dados['CO_NCM']==2063000]
dados716=dados[dados['CO_NCM']==2064100]
dados717=dados[dados['CO_NCM']==2064900]
dados718=dados[dados['CO_NCM']==2068000]
dados719=dados[dados['CO_NCM']==2069000]
dados720=dados[dados['CO_NCM']==2071100]
dados721=dados[dados['CO_NCM']==2071200]
dados722=dados[dados['CO_NCM']==2071300]
dados723=dados[dados['CO_NCM']==2071400]
dados724=dados[dados['CO_NCM']==2072400]
dados725=dados[dados['CO_NCM']==2072500]
dados726=dados[dados['CO_NCM']==2072600]
dados727=dados[dados['CO_NCM']==2072700]
dados728=dados[dados['CO_NCM']==2073200]
dados729=dados[dados['CO_NCM']==2073300]
dados730=dados[dados['CO_NCM']==2073400]
dados731=dados[dados['CO_NCM']==2073500]
dados732=dados[dados['CO_NCM']==2073600]
dados733=dados[dados['CO_NCM']==2074100]
dados734=dados[dados['CO_NCM']==2074200]
dados735=dados[dados['CO_NCM']==2074300]
dados736=dados[dados['CO_NCM']==2074400]
dados737=dados[dados['CO_NCM']==2074500]
dados738=dados[dados['CO_NCM']==2075100]
dados739=dados[dados['CO_NCM']==2075200]
dados740=dados[dados['CO_NCM']==2075300]
dados741=dados[dados['CO_NCM']==2075400]
dados742=dados[dados['CO_NCM']==2075500]
dados743=dados[dados['CO_NCM']==2076000]
dados744=dados[dados['CO_NCM']==2081000]
dados745=dados[dados['CO_NCM']==2082000]
dados746=dados[dados['CO_NCM']==2083000]
dados747=dados[dados['CO_NCM']==2084000]
dados748=dados[dados['CO_NCM']==2085000]
dados749=dados[dados['CO_NCM']==2086000]
dados750=dados[dados['CO_NCM']==2089000]
dados751=dados[dados['CO_NCM']==2090011]
dados752=dados[dados['CO_NCM']==2090019]
dados753=dados[dados['CO_NCM']==2090021]
dados754=dados[dados['CO_NCM']==2090029]
dados755=dados[dados['CO_NCM']==2090090]
dados756=dados[dados['CO_NCM']==2091011]
dados757=dados[dados['CO_NCM']==2091019]
dados758=dados[dados['CO_NCM']==2091021]
dados759=dados[dados['CO_NCM']==2091029]
dados760=dados[dados['CO_NCM']==2099000]
dados761=dados[dados['CO_NCM']==2101100]
dados762=dados[dados['CO_NCM']==2101200]
dados763=dados[dados['CO_NCM']==2101900]
dados764=dados[dados['CO_NCM']==2102000]
dados765=dados[dados['CO_NCM']==2109000]
dados766=dados[dados['CO_NCM']==2109100]
dados767=dados[dados['CO_NCM']==2109200]
dados768=dados[dados['CO_NCM']==2109300]
dados769=dados[dados['CO_NCM']==2109900]
dados770=dados[dados['CO_NCM']==2109911]
dados771=dados[dados['CO_NCM']==2109919]
dados772=dados[dados['CO_NCM']==2109920]
dados773=dados[dados['CO_NCM']==2109930]
dados774=dados[dados['CO_NCM']==2109940]
dados775=dados[dados['CO_NCM']==2109990]
dados776=dados[dados['CO_NCM']==9011110]
dados777=dados[dados['CO_NCM']==9011190]
dados778=dados[dados['CO_NCM']==9011200]
dados779=dados[dados['CO_NCM']==9012100]
dados780=dados[dados['CO_NCM']==9012200]
dados781=dados[dados['CO_NCM']==9019000]
dados782=dados[dados['CO_NCM']==10051000]
dados783=dados[dados['CO_NCM']==10059010]
dados784=dados[dados['CO_NCM']==10059090]

# %%
com = pd.concat([dados1,dados2,dados3,dados4,dados5,dados6,dados7,dados8,dados9,dados10,dados11,dados12,dados13,dados14,dados15,dados16,dados17,dados18,dados19,dados20,dados21,dados22,dados23,dados24,dados25,dados26,dados27,dados28,dados29,dados30,dados31,dados32,dados33,dados34,dados35,dados36,dados37,dados38,dados39,dados40,dados41,dados42,dados43,dados44,dados45,dados46,dados47,dados48,dados49,dados50,dados51,dados52,dados53,dados54,dados55,dados56,dados57,dados58,dados59,dados60,dados61,dados62,dados63,dados64,dados65,dados66,dados67,dados68,dados69,dados70,dados71,dados72,dados73,dados74,dados75,dados76,dados77,dados78,dados79,dados80,dados81,dados82,dados83,dados84,dados85,dados86,dados87,dados88,dados89,dados90,dados91,dados92,dados93,dados94,dados95,dados96,dados97,dados98,dados99,dados100,dados101,dados102,dados103,dados104,dados105,dados106,dados107,dados108,dados109,dados110,dados111,dados112,dados113,dados114,dados115,dados116,dados117,dados118,dados119,dados120,dados121,dados122,dados123,dados124,dados125,dados126,dados127,dados128,dados129,dados130,dados131,dados132,dados133,dados134,dados135,dados136,dados137,dados138,dados139,dados140,dados141,dados142,dados143,dados144,dados145,dados146,dados147,dados148,dados149,dados150,dados151,dados152,dados153,dados154,dados155,dados156,dados157,dados158,dados159,dados160,dados161,dados162,dados163,dados164,dados165,dados166,dados167,dados168,dados169,dados170,dados171,dados172,dados173,dados174,dados175,dados176,dados177,dados178,dados179,dados180,dados181,dados182,dados183,dados184,dados185,dados186,dados187,dados188,dados189,dados190,dados191,dados192,dados193,dados194,dados195,dados196,dados197,dados198,dados199,dados200,dados201,dados202,dados203,dados204,dados205,dados206,dados207,dados208,dados209,dados210,dados211,dados212,dados213,dados214,dados215,dados216,dados217,dados218,dados219,dados220,dados221,dados222,dados223,dados224,dados225,dados226,dados227,dados228,dados229,dados230,dados231,dados232,dados233,dados234,dados235,dados236,dados237,dados238,dados239,dados240,dados241,dados242,dados243,dados244,dados245,dados246,dados247,dados248,dados249,dados250,dados251,dados252,dados253,dados254,dados255,dados256,dados257,dados258,dados259,dados260,dados261,dados262,dados263,dados264,dados265,dados266,dados267,dados268,dados269,dados270,dados271,dados272,dados273,dados274,dados275,dados276,dados277,dados278,dados279,dados280,dados281,dados282,dados283,dados284,dados285,dados286,dados287,dados288,dados289,dados290,dados291,dados292,dados293,dados294,dados295,dados296,dados297,dados298,dados299,dados300,dados301,dados302,dados303,dados304,dados305,dados306,dados307,dados308,dados309,dados310,dados311,dados312,dados313,dados314,dados315,dados316,dados317,dados318,dados319,dados320,dados321,dados322,dados323,dados324,dados325,dados326,dados327,dados328,dados329,dados330,dados331,dados332,dados333,dados334,dados335,dados336,dados337,dados338,dados339,dados340,dados341,dados342,dados343,dados344,dados345,dados346,dados347,dados348,dados349,dados350,dados351,dados352,dados353,dados354,dados355,dados356,dados357,dados358,dados359,dados360,dados361,dados362,dados363,dados364,dados365,dados366,dados367,dados368,dados369,dados370,dados371,dados372,dados373,dados374,dados375,dados376,dados377,dados378,dados379,dados380,dados381,dados382,dados383,dados384,dados385,dados386,dados387,dados388,dados389,dados390,dados391,dados392,dados393,dados394,dados395,dados396,dados397,dados398,dados399,dados400,dados401,dados402,dados403,dados404,dados405,dados406,dados407,dados408,dados409,dados410,dados411,dados412,dados413,dados414,dados415,dados416,dados417,dados418,dados419,dados420,dados421,dados422,dados423,dados424,dados425,dados426,dados427,dados428,dados429,dados430,dados431,dados432,dados433,dados434,dados435,dados436,dados437,dados438,dados439,dados440,dados441,dados442,dados443,dados444,dados445,dados446,dados447,dados448,dados449,dados450,dados451,dados452,dados453,dados454,dados455,dados456,dados457,dados458,dados459,dados460,dados461,dados462,dados463,dados464,dados465,dados466,dados467,dados468,dados469,dados470,dados471,dados472,dados473,dados474,dados475,dados476,dados477,dados478,dados479,dados480,dados481,dados482,dados483,dados484,dados485,dados486,dados487,dados488,dados489,dados490,dados491,dados492,dados493,dados494,dados495,dados496,dados497,dados498,dados499,dados500,dados501,dados502,dados503,dados504,dados505,dados506,dados507,dados508,dados509,dados510,dados511,dados512,dados513,dados514,dados515,dados516,dados517,dados518,dados519,dados520,dados521,dados522,dados523,dados524,dados525,dados526,dados527,dados528,dados529,dados530,dados531,dados532,dados533,dados534,dados535,dados536,dados537,dados538,dados539,dados540,dados541,dados542,dados543,dados544,dados545,dados546,dados547,dados548,dados549,dados550,dados551,dados552,dados553,dados554,dados555,dados556,dados557,dados558,dados559,dados560,dados561,dados562,dados563,dados564,dados565,dados566,dados567,dados568,dados569,dados570,dados571,dados572,dados573,dados574,dados575,dados576,dados577,dados578,dados579,dados580,dados581,dados582,dados583,dados584,dados585,dados586,dados587,dados588,dados589,dados590,dados591,dados592,dados593,dados594,dados595,dados596,dados597,dados598,dados599,dados600,dados601,dados602,dados603,dados604,dados605,dados606,dados607,dados608,dados609,dados610,dados611,dados612,dados613,dados614,dados615,dados616,dados617,dados618,dados619,dados620,dados621,dados622,dados623,dados624,dados625,dados626,dados627,dados628,dados629,dados630,dados631,dados632,dados633,dados634,dados635,dados636,dados637,dados638,dados639,dados640,dados641,dados642,dados643,dados644,dados645,dados646,dados647,dados648,dados649,dados650,dados651,dados652,dados653,dados654,dados655,dados656,dados657,dados658,dados659,dados660,dados661,dados662,dados663,dados664,dados665,dados666,dados667,dados668,dados669,dados670,dados671,dados672,dados673,dados674,dados675,dados676,dados677,dados678,dados679,dados680,dados681,dados682,dados683,dados684,dados685,dados686,dados687,dados688,dados689,dados690,dados691,dados692,dados693,dados694,dados695,dados696,dados697,dados698,dados699,dados700,dados701,dados702,dados703,dados704,dados705,dados706,dados707,dados708,dados709,dados710,dados711,dados712,dados713,dados714,dados715,dados716,dados717,dados718,dados719,dados720,dados721,dados722,dados723,dados724,dados725,dados726,dados727,dados728,dados729,dados730,dados731,dados732,dados733,dados734,dados735,dados736,dados737,dados738,dados739,dados740,dados741,dados742,dados743,dados744,dados745,dados746,dados747,dados748,dados749,dados750,dados751,dados752,dados753,dados754,dados755,dados756,dados757,dados758,dados759,dados760,dados761,dados762,dados763,dados764,dados765,dados766,dados767,dados768,dados769,dados770,dados771,dados772,dados773,dados774,dados775,dados776,dados777,dados778,dados779,dados780,dados781,dados782,dados783,dados784])

# %%
dic = pd.read_csv('NCM_Comm.csv',encoding='ansi')

# %%
dic = dic.set_index('CO_NCM')
dic = dic.to_dict()
com = com.replace({'CO_NCM':dic['NO_NCM_POR']})

# %%
comg = com.groupby(['CO_NCM','CO_ANO'])

# %%
comgs = comg.sum()
comgs.reset_index(inplace=True)

# %%
comgs = comgs.sort_values(by=['CO_ANO','VL_FOB'],ascending=True)
comgs20 = comgs[comgs['CO_ANO']==2020]

# %%
fig, ax = plt.subplots(figsize=(15,8))

ax.barh(comgs20['CO_NCM'],comgs20['VL_FOB'])
# Out:
# <BarContainer object of 21 artists>

# %%
comgs97 = comgs[comgs['CO_ANO']==1997]

comgs98 = comgs[comgs['CO_ANO']==1998]
comgs98 = pd.concat([comgs97,comgs98])
comgs98 = comgs98.replace({1997:1998})
comgs98 = comgs98.groupby(['CO_NCM','CO_ANO'])
comgs98 = comgs98.sum()
comgs98.reset_index(inplace=True)

comgs99 = comgs[comgs['CO_ANO']==1999]
comgs99 = pd.concat([comgs98,comgs99])
comgs99 = comgs99.replace({1998:1999})
comgs99 = comgs99.groupby(['CO_NCM','CO_ANO'])
comgs99 = comgs99.sum()
comgs99.reset_index(inplace=True)

comgs00 = comgs[comgs['CO_ANO']==2000]
comgs00 = pd.concat([comgs99,comgs00])
comgs00 = comgs00.replace({1999:2000})
comgs00 = comgs00.groupby(['CO_NCM','CO_ANO'])
comgs00 = comgs00.sum()
comgs00.reset_index(inplace=True)


comgs01 = comgs[comgs['CO_ANO']==2001]
comgs01 = pd.concat([comgs00,comgs01])
comgs01 = comgs01.replace({2000:2001})
comgs01 = comgs01.groupby(['CO_NCM','CO_ANO'])
comgs01 = comgs01.sum()
comgs01.reset_index(inplace=True)


comgs02 = comgs[comgs['CO_ANO']==2002]
comgs02 = pd.concat([comgs01,comgs02])
comgs02 = comgs02.replace({2001:2002})
comgs02 = comgs02.groupby(['CO_NCM','CO_ANO'])
comgs02 = comgs02.sum()
comgs02.reset_index(inplace=True)


comgs03 = comgs[comgs['CO_ANO']==2003]
comgs03 = pd.concat([comgs02,comgs03])
comgs03 = comgs03.replace({2002:2003})
comgs03 = comgs03.groupby(['CO_NCM','CO_ANO'])
comgs03 = comgs03.sum()
comgs03.reset_index(inplace=True)

comgs04 = comgs[comgs['CO_ANO']==2004]
comgs04 = pd.concat([comgs03,comgs04])
comgs04 = comgs04.replace({2003:2004})
comgs04 = comgs04.groupby(['CO_NCM','CO_ANO'])
comgs04 = comgs04.sum()
comgs04.reset_index(inplace=True)


comgs05 = comgs[comgs['CO_ANO']==2005]
comgs05 = pd.concat([comgs04,comgs05])
comgs05 = comgs05.replace({2004:2005})
comgs05 = comgs05.groupby(['CO_NCM','CO_ANO'])
comgs05 = comgs05.sum()
comgs05.reset_index(inplace=True)

comgs06 = comgs[comgs['CO_ANO']==2006]
comgs06 = pd.concat([comgs05,comgs06])
comgs06 = comgs06.replace({2005:2006})
comgs06 = comgs06.groupby(['CO_NCM','CO_ANO'])
comgs06 = comgs06.sum()
comgs06.reset_index(inplace=True)

comgs07 = comgs[comgs['CO_ANO']==2007]
comgs07 = pd.concat([comgs06,comgs07])
comgs07 = comgs07.replace({2006:2007})
comgs07 = comgs07.groupby(['CO_NCM','CO_ANO'])
comgs07 = comgs07.sum()
comgs07.reset_index(inplace=True)


comgs08 = comgs[comgs['CO_ANO']==2008]
comgs08 = pd.concat([comgs07,comgs08])
comgs08 = comgs08.replace({2007:2008})
comgs08 = comgs08.groupby(['CO_NCM','CO_ANO'])
comgs08 = comgs08.sum()
comgs08.reset_index(inplace=True)


comgs09 = comgs[comgs['CO_ANO']==2009]
comgs09 = pd.concat([comgs08,comgs09])
comgs09 = comgs09.replace({2008:2009})
comgs09 = comgs09.groupby(['CO_NCM','CO_ANO'])
comgs09 = comgs09.sum()
comgs09.reset_index(inplace=True)


comgs10 = comgs[comgs['CO_ANO']==2010]
comgs10 = pd.concat([comgs09,comgs10])
comgs10 = comgs10.replace({2009:2010})
comgs10 = comgs10.groupby(['CO_NCM','CO_ANO'])
comgs10 = comgs10.sum()
comgs10.reset_index(inplace=True)


comgs11 = comgs[comgs['CO_ANO']==2011]
comgs11 = pd.concat([comgs10,comgs11])
comgs11 = comgs11.replace({2010:2011})
comgs11 = comgs11.groupby(['CO_NCM','CO_ANO'])
comgs11 = comgs11.sum()
comgs11.reset_index(inplace=True)


comgs12 = comgs[comgs['CO_ANO']==2012]
comgs12 = pd.concat([comgs11,comgs12])
comgs12 = comgs12.replace({2011:2012})
comgs12 = comgs12.groupby(['CO_NCM','CO_ANO'])
comgs12 = comgs12.sum()
comgs12.reset_index(inplace=True)

comgs13 = comgs[comgs['CO_ANO']==2013]
comgs13 = pd.concat([comgs12,comgs13])
comgs13 = comgs13.replace({2012:2013})
comgs13 = comgs13.groupby(['CO_NCM','CO_ANO'])
comgs13 = comgs13.sum()
comgs13.reset_index(inplace=True)

comgs14 = comgs[comgs['CO_ANO']==2014]
comgs14 = pd.concat([comgs13,comgs14])
comgs14 = comgs14.replace({2013:2014})
comgs14 = comgs14.groupby(['CO_NCM','CO_ANO'])
comgs14 = comgs14.sum()
comgs14.reset_index(inplace=True)


comgs15 = comgs[comgs['CO_ANO']==2015]
comgs15 = pd.concat([comgs14,comgs15])
comgs15 = comgs15.replace({2014:2015})
comgs15 = comgs15.groupby(['CO_NCM','CO_ANO'])
comgs15 = comgs15.sum()
comgs15.reset_index(inplace=True)


comgs16 = comgs[comgs['CO_ANO']==2016]
comgs16 = pd.concat([comgs15,comgs16])
comgs16 = comgs16.replace({2015:2016})
comgs16 = comgs16.groupby(['CO_NCM','CO_ANO'])
comgs16 = comgs16.sum()
comgs16.reset_index(inplace=True)


comgs17 = comgs[comgs['CO_ANO']==2017]
comgs17 = pd.concat([comgs16,comgs17])
comgs17 = comgs17.replace({2016:2017})
comgs17 = comgs17.groupby(['CO_NCM','CO_ANO'])
comgs17 = comgs17.sum()
comgs17.reset_index(inplace=True)

comgs18 = comgs[comgs['CO_ANO']==2018]
comgs18 = pd.concat([comgs17,comgs18])
comgs18 = comgs18.replace({2017:2018})
comgs18 = comgs18.groupby(['CO_NCM','CO_ANO'])
comgs18 = comgs18.sum()
comgs18.reset_index(inplace=True)


comgs19 = comgs[comgs['CO_ANO']==2019]
comgs19 = pd.concat([comgs18,comgs19])
comgs19 = comgs19.replace({2018:2019})
comgs19 = comgs19.groupby(['CO_NCM','CO_ANO'])
comgs19 = comgs19.sum()
comgs19.reset_index(inplace=True)


comgs20 = comgs[comgs['CO_ANO']==2020]
comgs20 = pd.concat([comgs19,comgs20])
comgs20 = comgs20.replace({2019:2020})
comgs20 = comgs20.groupby(['CO_NCM','CO_ANO'])
comgs20 = comgs20.sum()
comgs20.reset_index(inplace=True)

# %%
comgs97=comgs97.sort_values(by=['VL_FOB'],ascending=False)
comgs98=comgs98.sort_values(by=['VL_FOB'],ascending=False)
comgs99=comgs99.sort_values(by=['VL_FOB'],ascending=False)
comgs00=comgs00.sort_values(by=['VL_FOB'],ascending=False)
comgs01=comgs01.sort_values(by=['VL_FOB'],ascending=False)
comgs02=comgs02.sort_values(by=['VL_FOB'],ascending=False)
comgs03=comgs03.sort_values(by=['VL_FOB'],ascending=False)
comgs04=comgs04.sort_values(by=['VL_FOB'],ascending=False)
comgs05=comgs05.sort_values(by=['VL_FOB'],ascending=False)
comgs06=comgs06.sort_values(by=['VL_FOB'],ascending=False)
comgs07=comgs07.sort_values(by=['VL_FOB'],ascending=False)
comgs08=comgs08.sort_values(by=['VL_FOB'],ascending=False)
comgs09=comgs09.sort_values(by=['VL_FOB'],ascending=False)
comgs10=comgs10.sort_values(by=['VL_FOB'],ascending=False)
comgs11=comgs11.sort_values(by=['VL_FOB'],ascending=False)
comgs12=comgs12.sort_values(by=['VL_FOB'],ascending=False)
comgs13=comgs13.sort_values(by=['VL_FOB'],ascending=False)
comgs14=comgs14.sort_values(by=['VL_FOB'],ascending=False)
comgs15=comgs15.sort_values(by=['VL_FOB'],ascending=False)
comgs16=comgs16.sort_values(by=['VL_FOB'],ascending=False)
comgs17=comgs17.sort_values(by=['VL_FOB'],ascending=False)
comgs18=comgs18.sort_values(by=['VL_FOB'],ascending=False)
comgs19=comgs19.sort_values(by=['VL_FOB'],ascending=False)
comgs20=comgs20.sort_values(by=['VL_FOB'],ascending=False)

# %%
comgs_sum = pd.concat([comgs97,comgs98,comgs99,comgs00,comgs01,comgs02,comgs03,comgs04,comgs05,comgs06,comgs07,comgs08,comgs09,comgs10,comgs11,comgs12,comgs13,comgs14,comgs15,comgs16,comgs17,comgs18,comgs19,comgs20])
comgs_sum['BI_VL_FOB'] = comgs_sum['VL_FOB']/1000000000
comgs_sum['BI_VL_FOB'] = comgs_sum['BI_VL_FOB'].round(2)
comgs_sum
# Out:
#                CO_NCM  CO_ANO  CO_MES  CO_UNID  CO_PAIS  CO_VIA      CO_URF  \
# 264             Ferro    1997   59357    91570  3234332   27823  6953081549
# 96               Café    1997   14377    42256   716138    4041  1666630763
# 216    Farelo de Soja    1997    4109    13188   233862     640   569929544
# 431              Soja    1997    3081     9206   200922     669   383023533
# 48             Açúcar    1997    4473    12006   252834    1132   452911658
# ..                ...     ...     ...      ...      ...     ...         ...
# 12        Gás Natural    2020    3432     5110   244049    1631   337566950
# 17              Prata    2020   25263    38990  1144340   15379  3169543839
# 10   Farinha de trigo    2020   31388    48320  1909900   12962  2924696839
# 6              Carvão    2020    4230     6390   206337    2800   541133484
# 13           Manganês    2020    2525     3870   137693     714   313063806
#
#        QT_ESTAT   KG_LIQUIDO      VL_FOB  BI_VL_FOB
# ...

# %%
colors = dict(zip(
    ['Açúcar','Algodão','Aluminio','Cacau',
     'Café','Carne','Carvão','Cobre',
     'Estanho','Farelo de Soja','Farinha de trigo','Ferro',
     'Gás Natural','Manganês','Milho','Óleo de Soja',
     'Ouro','Petróleo','Prata','Soja',
     'Suco de Laranja','Trigo'],
    ['#adb0ff', '#ffb3ff', '#90d595', '#e48381',
     '#aafbff', '#f7bb5f', '#eafb50','#adb0ff', 
     '#ffb3ff', '#90d595', '#e48381','#aafbff',
     '#f7bb5f', '#eafb50','#adb0ff', '#ffb3ff', 
     '#90d595', '#e48381','#aafbff', '#f7bb5f', 
     '#eafb50','#adb0ff']))
image = plt.imread('bj.png')

# %%
current_year = comgs20['CO_ANO'].max()
current_year
# Out:
# 2020

# %%
fig, ax = plt.subplots(figsize=(15,10))
comgs20 = comgs20[::-1]
current_year = comgs20['CO_ANO'].max()
ax.barh(comgs20['CO_NCM'],comgs20['VL_FOB'],height=0.9,color=[colors[x] for x in comgs20['CO_NCM']])
for i, (value, name) in enumerate(zip(comgs20['VL_FOB'], comgs20['CO_NCM'])):
    ax.text(value, i,     name,            ha='right')  # Tokyo: name
    ax.text(value, i,     value,           ha='left')   # 38194.2: value
ax.text(1, 0.4, current_year, transform=ax.transAxes, size=46, ha='right')
ax.text(0.5, 0.4, 'TESTE', transform=ax.transAxes, size=46, ha='center')
# Out:
# Text(0.5, 0.4, 'TESTE')

# %%
fig, ax = plt.subplots(figsize=(15, 8))
def draw_barchart(year):
    comgs_map = comgs_sum[comgs_sum['CO_ANO'].eq(year)].sort_values(by='VL_FOB', ascending=True).tail(10)
    ax.clear()
    ax.barh(comgs_map['CO_NCM'],comgs_map['BI_VL_FOB'],height=0.9,color=[colors[x] for x in comgs_map['CO_NCM']])
    dx = comgs_map['BI_VL_FOB'].max() / 200
    current_year = comgs_map['CO_ANO'].max()
    for i, (value, name) in enumerate(zip(comgs_map['BI_VL_FOB'], comgs_map['CO_NCM'])):
        ax.text(value, i,     name,            ha='right',fontsize=15)  # Tokyo: name
        ax.text(value, i,     value,           ha='left', fontsize=15)   # 38194.2: value
        ax.text(1, 0.4, year, transform=ax.transAxes, color='#777777', size=46, ha='right', weight=800)
        ax.text(1, 0.3, 'Murilo Faix', transform=ax.transAxes, size=50, ha='right')
        ax.text(1, 0.25, 'Agricultura Digital e Data Science', transform=ax.transAxes, size=13, ha='right')
        ax.text(0, 1.06, 'Valor em Bilhões de U$', transform=ax.transAxes, size=20, color='#777777')
        ax.xaxis.set_ticks_position('top')
    ax.tick_params(axis='x', colors='#777777', labelsize=12)
    ax.set_yticks([])
    ax.margins(0, 0.01)
    ax.grid(which='major', axis='x', linestyle='-')
    ax.set_axisbelow(True)
    ax.text(0, 1.1, 'Exportação das Principais Commodities Brasileiras de 97 a 19',
            transform=ax.transAxes, size=24, weight=600, ha='left')
    ax.text(1, 0, 'Fonte: MDIC', transform=ax.transAxes, ha='right',
            color='#777777', bbox=dict(facecolor='white', alpha=0.8, edgecolor='white'))
    plt.box(False)
    plt.tight_layout
draw_barchart(2019)

# %%
import matplotlib.animation as animation
from IPython.display import HTML
fig, ax = plt.subplots(figsize=(15, 8))
animator = animation.FuncAnimation(fig, draw_barchart, frames=range(1997, 2020),interval=750)
animator.save('teste.mp4',dpi=300)
